# %% [markdown]
# # nr prim

# %%
# 13 - 1, 13 
# 29 - 1, 29
# 17 - 1, 17

# 15 - 1, 3, 5, 15

import math

def este_prim(n):
    if n < 2: return False
    # if n == 2: return False
    if n%2 == 0: return False

    limita = int(math.sqrt(n))
    print(math.sqrt(n))
    print("Radacina patrata aprox: ", str(limita))
    for i in range (3, limita+1, 2):
        if n % i == 0:
            print("divizor gasit", str(i))
            return False
    return True
    

numar = int(input("Introdu un nr pt verificare:"))
print(f"Status nr prim: {este_prim(numar)}")
# Out:
# Introdu un nr pt verificare: 13
# 3.605551275463989
# Radacina patrata aprox:  3
# Status nr prim: True

# %%
for i in range (3, 17, 3):
    print(i)
# Out:
# 3
# 6
# 9
# 12
# 15

# %%
import math

def este_prim2(n):
    limita = int(n/2)
    nr_divizori = 0
    for i in range (2, limita+1):
        if n % i == 0:
            nr_divizori+=1
    if nr_divizori == 0: return True
    else: return False
    

numar = int(input("Introdu un nr pt verificare:"))
print(f"Status nr prim: {este_prim2(numar)}")

# %% [markdown]
# ## Cautarea binara

# %%
print(7 //2)
print(7 / 2)
# Out:
# 3
# 3.5

# %%
def cautare_binara(lista, tinta):
    stanga = 0
    dreapta = len(lista)-1

    while stanga <= dreapta:
        mijloc = (stanga + dreapta) // 2
        if lista[mijloc] == tinta:
            return mijloc
        elif lista[mijloc] < tinta:
            stanga = mijloc + 1
        else: dreapta = mijloc -1
    return -1
        
    

lista_nr = [10, 20, 30, 40, 50, 60, 70, 80, 90]
tinta = 70
index = cautare_binara(lista_nr, tinta)

if index != -1:
    print("Elementul e gasit pe pozitia", str(index))
else: print("Elementul nu exista")
# Out:
# Elementul e gasit pe pozitia 6

# %% [markdown]
# ### Matrix Bubble sort & binary search

# %%
matrice = [
    [45, 12, 20],
    [90, 15, 3],
    [7, 1, 80]
]

# pasul 1: 

# { (0,0): 45, .....}
lista_aplatizata = []
for rand in matrice:
    for elem in rand:
        lista_aplatizata.append(elem)

print(lista_aplatizata)
# Out:
# [45, 12, 20, 90, 15, 3, 7, 1, 80]

# %%
# bubble sort
def bubble_sort(lista):
    n = len(lista)
    for i in range(n):
        for j in range(0,n - i - 1):
            if lista[j] > lista[j+1]:
                lista[j], lista[j+1] = lista[j+1], lista[j]
    return lista

lista_sortata = bubble_sort(lista_aplatizata)

# %%
index = cautare_binara(lista_sortata, 15)

if index != -1:
    print("Elementul exista in matrice")
else: print("Elementul nu exista in matrice")
# Out:
# Elementul exista in matrice

# %% [markdown]
# ### Dictionare

# %%
student = {
    "nume": "Andreea",
    "varsta": 23,
    "oras": "Cluj-Napoca",
    "note": [9, 10, 8]
}

print(student["nume"])

print(student.get("nume1", "empty"))

student["nume"] = "Andreea2"
print(student)

cautare = 23

for key, value in student.items():
    if value == cautare:
        print(key, value)

for key in student.keys():
    print(key)

for value in student.values():
    print(value)
# Out:
# Andreea
# empty
# {'nume': 'Andreea2', 'varsta': 23, 'oras': 'Cluj-Napoca', 'note': [9, 10, 8]}
# varsta 23
# nume
# varsta
# oras
# note
# Andreea2
# 23
# Cluj-Napoca
# [9, 10, 8]

# %%
# 1.De făcut o funcție de căutare si afișați toate datele corespondente oricărui nume date de la tastatura
# 2. Cautare dupa o conditie pe o "coloana" (ex: toti studentii din Cluj)
date_studenti = {
    "nume":   ["Ana", "Bogdan", "Carmen", "Dan"],
    "varsta": [23, 34, 45, 28],
    "oras":   ["Cluj", "Iasi", "Brasov", "Cluj"],
    "nota":   [9.5, 7.0, 8.5, 6.0]
}

def functie_cautare(dictionar):
    # cautare = input()
    cautare = "Ana"
    index = 0
    varsta = 0
    oras = ""
    nota = 0
    for key, lista_val in dictionar.items():
        print(key, lista_val)
        if key == "nume":
            index = lista_val.index(cautare)
        elif key == "varsta":
            varsta = lista_val[index]
        elif key == "oras":
            oras  = lista_val[index]
        else: nota = lista_val[index]
                
    print(f"Gasit numele {cautare} cu valori: {varsta}, {oras}, {nota}")
    

functie_cautare(date_studenti)
# Out:
# nume ['Ana', 'Bogdan', 'Carmen', 'Dan']
# varsta [23, 34, 45, 28]
# oras ['Cluj', 'Iasi', 'Brasov', 'Cluj']
# nota [9.5, 7.0, 8.5, 6.0]
# Gasit numele Ana cu valori: 23, Cluj, 9.5

# %% [markdown]
# ## TUPLU

# %%
tuplu = (1,2,3,4)
print(tuplu)

print(tuplu[-1])


lista = [1,2,3,4]
def calc_max_min(lista):
    return max(lista), min(lista)

minim, maxim = calc_max_min(lista)
print(minim, maxim)

tuplu1 = (4,5)
tuplu2 = tuplu+tuplu1
print(tuplu+tuplu1)

print(tuplu2.index(1))
print(tuplu2.count(4))
# Out:
# (1, 2, 3, 4)
# 4
# 4 1
# (1, 2, 3, 4, 4, 5)
# 0
# 2

# %%
tuplu3 = (1,2, [3,4,5,6])
tuplu3[2].append(7)
print(tuplu3)

d = {(Andreea,): 1, (Bogdan,): 2}
# Out:
# (1, 2, [3, 4, 5, 6, 7])

# %%
# HASH FUNCTION

bucket 
n 
hash_function(key)
    key % n + 100

Bogdan -> hash_function(Bogdan) -> 1293X-00a0asd -> [Bogdan]
Andreea ->  hash_function(Andreea) -> 122454X-00a0asd -> [Andreea]
Andreea ->  hash_function2(Andreea) -> 122454X-00a23sd -> [Andreea]

# %% [markdown]
# ## SET

# %%
words = {"python", "sql", "javascript"}
print(words)

words.add("pandas")
print(words)

words.remove("pandas")
# Out:
# {'sql', 'javascript', 'python'}
# {'sql', 'pandas', 'javascript', 'python'}

# %%
# ============================================
# Exercițiul 1: Curățare + deduplicare email-uri (set)
# ============================================
# Avem o lista de email-uri introduse de useri, cu inconsistente:
# spatii, majuscule/minuscule diferite si duplicate.
# Cerinta: curata fiecare email (fara spatii, litere mici) si elimina duplicatele.

emailuri_brute = [
    " Ana@Test.com", "bogdan@test.com ", "ANA@test.com",
    "carmen@test.com", "bogdan@test.com", " Dan@Test.Com"
]

# %%
# ============================================
# Exercițiul 2: Tupluri - orase si coordonate GPS
# ============================================
# Fiecare oras e reprezentat ca un tuplu (nume, latitudine, longitudine).
# Cerinte:
#  a) gaseste coordonatele unui oras dupa nume
#  b) sorteaza orasele dupa latitudine (de la nord la sud)

lista_orase = [
    ("Bucuresti", 44.4268, 26.1025),
    ("Cluj-Napoca", 46.7712, 23.6236),
    ("Iasi", 47.1585, 27.6014),
    ("Timisoara", 45.7489, 21.2087),
    ("Constanta", 44.1598, 28.6348),
]

# a)
oras_cautat = input()
for date_oras in lista_orase:
    if oras_cautat == date_oras[0]:
        print(date_oras)

    
# b)
orase_sortate = sorted(lista_orase, key = lambda date_oras: date_oras[1], reverse = True)
print(orase_sortate)
# Out:
#  Iasi
# ('Iasi', 47.1585, 27.6014)
# [('Iasi', 47.1585, 27.6014), ('Cluj-Napoca', 46.7712, 23.6236), ('Timisoara', 45.7489, 21.2087), ('Bucuresti', 44.4268, 26.1025), ('Constanta', 44.1598, 28.6348)]

# %%
## API
import requests
import json

raspuns = requests.get("https://jsonplaceholder.typicode.com/users")
print(raspuns.status_code)
# 200 - cu succes
# 500 - problema pe server
# 400 - problema e la mine - am apelat gresit

utilizatori = raspuns.json()
print(utilizatori)
# Out:
# 200
# ...

# %%
# print(utilizatori[0])
print(json.dumps(utilizatori[0], indent=2, ensure_ascii=True))
# Out:
# {
#   "id": 1,
#   "name": "Leanne Graham",
#   "username": "Bret",
#   "email": "Sincere@april.biz",
#   "address": {
#     "street": "Kulas Light",
#     "suite": "Apt. 556",
#     "city": "Gwenborough",
#     "zipcode": "92998-3874",
#     "geo": {
#       "lat": "-37.3159",
#       "lng": "81.1496"
#     }
#   },
#   "phone": "1-770-736-8031 x56442",
#   "website": "hildegard.org",
#   "company": {
#     "name": "Romaguera-Crona",
#     "catchPhrase": "Multi-layered client-server neural-net",
#     "bs": "harness real-time e-markets"
#   }
# }

# %%
def selecteaza_datele(util):
    return {
        "name": util.get("name"),
        "username": util["username"],
        "street": util["address"]["street"],
        "lat": util["address"]["geo"]["lat"],
        "long": util["address"]["geo"]["lng"]
    }

utilizatori_selectati= [selecteaza_datele(u) for u in utilizatori]
# print(json.dumps(utilizatori_selectati, indent=2, ensure_ascii=True))

# orase_sortate = sorted(lista_orase, key = lambda date_oras: date_oras[1], reverse = True)


lista_sortata = sorted(utilizatori_selectati, key = lambda dictionar: dictionar["name"])
print(json.dumps(lista_sortata, indent=2, ensure_ascii=True))
# Out:
# [
#   {
#     "name": "Chelsey Dietrich",
#     "username": "Kamren",
#     "street": "Skiles Walks",
#     "lat": "-31.8129",
#     "long": "62.5342"
#   },
#   {
#     "name": "Clementina DuBuque",
#     "username": "Moriah.Stanton",
#     "street": "Kattie Turnpike",
#     "lat": "-38.2386",
#     "long": "57.2232"
#   },
#   {
#     "name": "Clementine Bauch",
#     "username": "Samantha",
#     "street": "Douglas Extension",
#     "lat": "-68.6102",
#     "long": "-47.0653"
#   },
#   {
#     "name": "Ervin Howell",
#     "username": "Antonette",
#     "street": "Victor Plains",
#     "lat": "-43.9509",
#     "long": "-34.4618"
#   },
#   {
#     "name": "Glenna Reichert",
#     "username": "Delphine",
#     "street": "Dayna Park",
#     "lat": "24.6463",
#     "long": "-168.8889"
#   },
#   {
#     "name": "Kurtis Weissnat",
#     "username": "Elwyn.Skiles",
#     "street": "Rex Trail",
#     "lat": "24.8918",
#     "long": "21.8984"
#   },
#   {
#     "name": "Leanne Graham",
# ...

# %%
# time complexity - de citit

lista = [1,2,3,4,5]

for i in lista:
    print("for 1 \n")
    for j in lista:
        print("\t for 2 \n ")
        for z in lista:
            print("\t\t for 3")

# for i -> 0 n
#     for j -> 0 -> 1 -> 2 m
#         for z -> 0,1,2,3,4,5 p


# # n x m x p - nr iteratii

# # n x n x n

# # O(n^3)
# Out:
# for 1
#
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# for 1
#
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# for 1
#
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 		 for 3
# 	 for 2
#
# 		 for 3
# ...
